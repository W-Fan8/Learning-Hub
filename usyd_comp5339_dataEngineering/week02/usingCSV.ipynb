# %%
import csv
import pprint

data = list(csv.DictReader(open('MajorPowerStations_v2.csv')))
pprint.pprint(data[0])
# Out:
# {'CLASS': 'Renewable',
#  'COMMENT': 'Hydro',
#  'DESCRIPTION': 'A facility used for the generation of electrical power for '
#                 'distribution',
#  'FEATURETYPE': 'Power Station',
#  'FID': '120',
#  'GENERATIONMW': '28',
#  'GENERATIONTYPE': 'Hydroelectric (Gravity)',
#  'GENERATORNUMBER': '1',
#  'LATITUDE': '-42.507695',
#  'LONGITUDE': '146.64696',
#  'NAME': 'Repulse',
#  'OBJECTID': '1',
#  'OPERATIONALSTATUS': 'Operational',
#  'OWNER': 'Hydro-Electric Corporation (Tasmania)',
#  'PRIMARYFUELTYPE': 'Water',
#  'PRIMARYSUBFUELTYPE': '',
#  'REVISED': '20171211',
#  'SPATIALCONFIDENCE': '5',
#  'STATE': 'Tasmania',
#  'SUBURB': 'Ouse'}

# %%
import pandas as pd

df = pd.read_csv("MajorPowerStations_v2.csv")
df.head()
# Out:
#    OBJECTID    FEATURETYPE                                        DESCRIPTION  \
# 0         1  Power Station  A facility used for the generation of electric...
# 1         2  Power Station  A facility used for the generation of electric...
# 2         3  Power Station  A facility used for the generation of electric...
# 3         4  Power Station  A facility used for the generation of electric...
# 4         5  Power Station  A facility used for the generation of electric...
#
#        CLASS    FID          NAME OPERATIONALSTATUS  \
# 0  Renewable  120.0       Repulse       Operational
# 1  Renewable  143.0        Gordon       Operational
# 2  Renewable  134.0  John Butters       Operational
# 3  Renewable  128.0       Tribute       Operational
# 4  Renewable  137.0       Bastyan       Operational
#
#                                    OWNER           GENERATIONTYPE  \
# 0  Hydro-Electric Corporation (Tasmania)  Hydroelectric (Gravity)
# ...

# %%
missing_values = ["--", "<Null>"]
df2 = pd.read_csv("MajorPowerStations_v2.csv",na_values=missing_values)
df2.head()
# Out:
#    OBJECTID    FEATURETYPE                                        DESCRIPTION  \
# 0         1  Power Station  A facility used for the generation of electric...
# 1         2  Power Station  A facility used for the generation of electric...
# 2         3  Power Station  A facility used for the generation of electric...
# 3         4  Power Station  A facility used for the generation of electric...
# 4         5  Power Station  A facility used for the generation of electric...
#
#        CLASS    FID          NAME OPERATIONALSTATUS  \
# 0  Renewable  120.0       Repulse       Operational
# 1  Renewable  143.0        Gordon       Operational
# 2  Renewable  134.0  John Butters       Operational
# 3  Renewable  128.0       Tribute       Operational
# 4  Renewable  137.0       Bastyan       Operational
#
#                                    OWNER           GENERATIONTYPE  \
# 0  Hydro-Electric Corporation (Tasmania)  Hydroelectric (Gravity)
# ...

# %%
df2['GENERATIONMW'] = df2['GENERATIONMW'].astype(int)

# %%
df2.head()
# Out:
#    OBJECTID    FEATURETYPE                                        DESCRIPTION  \
# 0         1  Power Station  A facility used for the generation of electric...
# 1         2  Power Station  A facility used for the generation of electric...
# 2         3  Power Station  A facility used for the generation of electric...
# 3         4  Power Station  A facility used for the generation of electric...
# 4         5  Power Station  A facility used for the generation of electric...
#
#        CLASS    FID          NAME OPERATIONALSTATUS  \
# 0  Renewable  120.0       Repulse       Operational
# 1  Renewable  143.0        Gordon       Operational
# 2  Renewable  134.0  John Butters       Operational
# 3  Renewable  128.0       Tribute       Operational
# 4  Renewable  137.0       Bastyan       Operational
#
#                                    OWNER           GENERATIONTYPE  \
# 0  Hydro-Electric Corporation (Tasmania)  Hydroelectric (Gravity)
# ...

# %%
import pandas as pd
