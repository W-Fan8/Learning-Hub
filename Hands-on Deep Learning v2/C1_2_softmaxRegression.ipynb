# %%
import torch

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
# 回归：是估计一个连续值 - 单连续输出、自然区间
# 分类：预测一个离散类别 - 多输出、输出i是预测为第i类的置信度

# 从regression到classification，即one-hot编码
# softmax，交叉熵损失
'''
    softmax regression 是一个多分类模型
    使用softmax操作得到每个类的预测置信度
    使用交叉熵来衡量预测和标号的区别
'''
# Out:
# '\n    softmax regression 是一个多分类模型\n    使用softmax操作得到每个类的预测置信度\n    使用交叉熵来衡量预测和标号的区别\n'

# %%
''' 
    L2 loss 均方损失
    L1 loss 绝对值损失函数
    Huber's Robust loss 结合L1和L2的优点

'''

# %%
# %matplotlib inline
import torchvision
from torch.utils import data
from torchvision import transforms
from d2l import torch as d2l
