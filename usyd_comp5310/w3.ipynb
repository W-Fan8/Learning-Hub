# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("WFH-Survey-Responses-NSW.csv")
df
# Out:
#       Response ID  What year were you born? What is your gender?  \
# 0               1                      1972               Female
# 1               2                      1972                 Male
# 2               3                      1982                 Male
# 3               4                      1987               Female
# 4               5                      1991                 Male
# ...           ...                       ...                  ...
# 1502         1503                      1995                 Male
# 1503         1504                      1990               Female
# 1504         1505                      1998                 Male
# 1505         1506                      1968               Female
# 1506         1507                      1980                 Male
#
#      Which of the following best describes your industry?  \
# 0                                         Manufacturing
# 1                                       Wholesale Trade
# ...

# %%
import csv

with open("WFH-Survey-Responses-NSW.csv") as csv_file:
    reader = csv.reader(csv_file, delimiter=",")

    headers = next(reader)
    #print(headers)
    for row in reader:
        print(row)
# Out:
# ['1', '1972', 'Female', 'Manufacturing', 'Food Product Manufacturing', 'Clerical and administrative ', 'Other Clerical and Administrative ', 'Between 20 and 199', 'No', 'Couple with no dependent children', 'More than 5 years', 'Regional', '0%', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', '', '', '', '']
# ['2', '1972', 'Male', 'Wholesale Trade', 'Other Goods Wholesaling', 'Managers', 'Chief Executives, General Managers and Legislators', 'Between 1 and 4', 'Yes', 'Couple with dependent children', 'More than 5 years', 'Metro', '20%', 'Somewhat agree', 'Somewhat agree', 'Somewhat agree', 'Somewhat agree', 'Somewhat agree', 'Somewhat agree', '', '', '', '']
# ...

# %%
apples = pd.Series([3,2,0,1])
apples[2]
# Out:
# 0

# %%
apples_dic = {'d1':3,'d2':2}
apples = pd.Series(apples_dic)
apples[1]
# Out:
# 2

# %%
zz = pd.DataFrame({"a":apples,"b":apples})
zz
# Out:
#     a  b
# d1  3  3
# d2  2  2

# %%
zz.iloc[0]
# Out:
# a    3
# b    3
# Name: d1, dtype: int64

# %%
df.tail(4)
# Out:
#       Response ID  What year were you born? What is your gender?  \
# 1503         1504                      1990               Female
# 1504         1505                      1998                 Male
# 1505         1506                      1968               Female
# 1506         1507                      1980                 Male
#
#      Which of the following best describes your industry?  \
# 1503                                    Wholesale Trade
# 1504                  Health Care and Social Assistance
# 1505                  Transport, Postal and Warehousing
# 1506           Information Media and Telecommunications
#
#      Which of the following best describes your industry? (Detailed)  \
# 1503    Grocery, Liquor and Tobacco Product Wholesaling
# 1504                                          Hospitals
# 1505                            Air and Space Transport
# 1506                        Telecommunications Services
#
# ...

# %%
df[df["My organisation encouraged people to work remotely"].isnull()]
# Out:
#       Response ID  What year were you born? What is your gender?  \
# 0               1                      1972               Female
# 6               7                      1973                 Male
# 10             11                      1980               Female
# 11             12                      1989                 Male
# 15             16                      1959                 Male
# ...           ...                       ...                  ...
# 1451         1452                      1986               Female
# 1462         1463                      1966               Female
# 1488         1489                      1989               Female
# 1492         1493                      1987                 Male
# 1495         1496                      1961               Female
#
#      Which of the following best describes your industry?  \
# 0                                         Manufacturing
# 6                      Financial and Insurance Services
# ...

# %%
df.rename(columns={
    "What is your gender?": "gender"}).head()
# Out:
#    Response ID  What year were you born?  gender  \
# 0            1                      1972  Female
# 1            2                      1972    Male
# 2            3                      1982    Male
# 3            4                      1987  Female
# 4            5                      1991    Male
#
#   Which of the following best describes your industry?  \
# 0                                      Manufacturing
# 1                                    Wholesale Trade
# 2         Electricity, Gas, Water and Waste Services
# 3    Professional, Scientific and Technical Services
# 4                  Transport, Postal and Warehousing
#
#   Which of the following best describes your industry? (Detailed)  \
# 0                         Food Product Manufacturing
# 1                            Other Goods Wholesaling
# 2                                         Gas Supply
# 3    Professional, Scientific and Technical Services
# 4                                    Other Transport
#
# ...

# %%
df.isnull().sum()
# Out:
# Response ID                                                                                          0
# What year were you born?                                                                             0
# What is your gender?                                                                                 0
# Which of the following best describes your industry?                                                 0
# Which of the following best describes your industry? (Detailed)                                      0
# Which of the following best describes your current occupation?                                       0
# Which of the following best describes your current occupation? (Detailed)                            0
# How many people are currently employed by your organisation?                                         0
# Do you manage people as part of your current occupation?                                           136
# ...

# %%
df[df["My organisation encouraged people to work remotely"].isnull()]
# Out:
#       Response ID  What year were you born? What is your gender?  \
# 0               1                      1972               Female
# 6               7                      1973                 Male
# 10             11                      1980               Female
# 11             12                      1989                 Male
# 15             16                      1959                 Male
# ...           ...                       ...                  ...
# 1451         1452                      1986               Female
# 1462         1463                      1966               Female
# 1488         1489                      1989               Female
# 1492         1493                      1987                 Male
# 1495         1496                      1961               Female
#
#      Which of the following best describes your industry?  \
# 0                                         Manufacturing
# 6                      Financial and Insurance Services
# ...
