# %%
import pandas as pd

kpmg_xlsx = pd.ExcelFile('KPMG_VI_New_raw_data_update_final.xlsx')

# %%
sheets = ['Transactions', 'NewCustomerList', 'CustomerDemographic', 'CustomerAddress']

# %%
dfs = {}
for sheet in sheets:
    dfs[sheet] = pd.read_excel(kpmg_xlsx, sheet_name=sheet)

kpmg_xlsx.close()
# Out:
# /var/folders/zg/1pb8nfp5473d_0jl7b7d8jyw0000gn/T/ipykernel_45824/1695149278.py:3: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   dfs[sheet] = pd.read_excel(kpmg_xlsx, sheet_name=sheet)
# /var/folders/zg/1pb8nfp5473d_0jl7b7d8jyw0000gn/T/ipykernel_45824/1695149278.py:3: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   dfs[sheet] = pd.read_excel(kpmg_xlsx, sheet_name=sheet)

# %%
transactions = dfs['Transactions']
newCustomerList = dfs['NewCustomerList']
customerDemographic = dfs['CustomerDemographic']
customerAddress = dfs['CustomerAddress']

# %%
# right: transaction_id

#incorrect_values = transactions[transactions['online_order']<=0 | transactions['online_order'].isnull()]
incorrect_values = transactions[transactions['product_first_sold_date'].isnull()]
#incorrect_values = transactions[transactions['standard_cost']<=0]
incorrect_values
# Out:
#        transaction_id  product_id  customer_id  transaction_date  \
# 136               137           0          431             43001
# 159               160           0         3300             42974
# 366               367           0         1614             42804
# 406               407           0         2559             42900
# 676               677           0         2609             42918
# ...               ...         ...          ...               ...
# 19340           19341           0          443             43095
# 19383           19384           0         2407             42897
# 19793           19794           0         2860             42748
# 19859           19860           0         2468             42910
# 19871           19872           0           61             42811
#
#        online_order order_status brand product_line product_class  \
# 136             0.0     Approved   NaN          NaN           NaN
# ...

# %%
#incorrect_values = newCustomerList[newCustomerList['Value']<=0]
incorrect_values = newCustomerList[newCustomerList['DOB'].isnull()]

incorrect_values
# Out:
#     first_name    last_name gender  past_3_years_bike_related_purchases DOB  \
# 983      Normy     Goodinge      U                                    5 NaT
# 984      Hatti     Carletti      U                                   35 NaT
# 985   Rozamond       Turtle      U                                   69 NaT
# 986      Tamas      Swatman      U                                   65 NaT
# 987      Tracy   Andrejevic      U                                   71 NaT
# 988     Agneta      McAmish      U                                   66 NaT
# 989      Gregg      Aimeric      U                                   52 NaT
# 990      Johna       Bunker      U                                   93 NaT
# 991    Harlene         Nono      U                                   69 NaT
# 992   Gerianne       Kaysor      U                                   15 NaT
# 993     Chicky      Sinclar      U                                   43 NaT
# ...

# %%
#incorrect_values = customerDemographic[customerDemographic['tenure']<=0]
#incorrect_values = customerDemographic[customerDemographic['DOB'].isnull()]
incorrect_values = customerDemographic
incorrect_values
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp       F
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995         3996         Rosalia   Halgarth  Female
# 3996         3997          Blanch     Nisuis  Female
# 3997         3998          Sarene    Woolley       U
# 3998         3999       Patrizius        NaN    Male
# 3999         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 1953-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# 2                                      61 1954-01-20      Recruiting Manager
# ...

# %%
incorrect_values = customerAddress[customerAddress['property_valuation']<=0]
incorrect_values
# Out:
# Empty DataFrame
# Columns: [customer_id, address, postcode, state, country, property_valuation]
# Index: []

# %%
duplicated_rows = transactions[transactions.duplicated()]
duplicated_rows
# Out:
# Empty DataFrame
# Columns: [transaction_id, product_id, customer_id, transaction_date, online_order, order_status, brand, product_line, product_class, product_size, list_price, standard_cost, product_first_sold_date]
# Index: []
