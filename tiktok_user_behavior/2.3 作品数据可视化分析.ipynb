# %% [markdown]
# # 抖音用户数据分析
# $——2.数据可视化分析—2.3 作品特征分析$

# %%
import pandas as pd
import numpy as np

from pyecharts.charts import *
from pyecharts import options as opts

# %% [markdown]
# ## 0. 绘图函数封装

# %% [markdown]
# 绘图函数已隐藏，后续的绘图流程也是，请通过fork项目展开查看

# %%
def line_chart(t, data):
    chart = (
        Line(init_opts = opts.InitOpts(theme='light', width='500px', height='300px'))
        .add_xaxis([i[0] for i in data])
        .add_yaxis(
            '',
            [i[1] for i in data],
            is_symbol_show=False,
            areastyle_opts=opts.AreaStyleOpts(opacity=1, color="cyan")
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(title=t),
            xaxis_opts=opts.AxisOpts(type_="category", boundary_gap=True),
            yaxis_opts=opts.AxisOpts(
                type_="value",
                axistick_opts=opts.AxisTickOpts(is_show=True),
                splitline_opts=opts.SplitLineOpts(is_show=True),
            ),
        )
    )
    return chart

# %%
def pie_chart(t, data_pair):
    # 新建一个饼图
    chart = (
        Pie(init_opts=opts.InitOpts(theme='light', width='550px', height='300px'))
        .add('', data_pair ,radius=["30%", "45%"], # 半径范围，内径和外径
            label_opts=opts.LabelOpts(formatter="{b}: {d}%") # 标签设置，{d}表示显示百分比
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(
                title=t
             ),
            legend_opts=opts.LegendOpts(pos_left="0%",pos_top="55",orient='vertical')
        )
    )
    return chart

# %% [markdown]
# ## 3. 作品特征分析

# %% [markdown]
# ### 3.0 数据读取

# %%
df =  pd.read_csv('/home/mw/input/somnus8660/douyin_dataset.csv')
del df['Unnamed: 0']
item_df = pd.read_csv('作品特征.csv')
item_df.head()
# Out:
#    item_id   浏览量  点赞量   发布城市     背景音乐
# 0        0    24    0   24.0    220.0
# 1        1  1309    5   63.0    574.0
# 2        3     2    0    7.0  26289.0
# 3        4   613    3  146.0    162.0
# 4        7     2    0   33.0    540.0

# %% [markdown]
# ### 3.1 作品各日发布情况

# %%
# 统计各日发布的作品数
data = df.groupby(['date']).agg({'item_id':pd.Series.nunique}).reset_index().values.tolist()
line_chart("各日单日作品发布量", data).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="bfe2af9568874016839da0efa472f80b" style="width:500px; height:300px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_bfe2af9568874016839da0efa472f80b = echarts.init(
#             document.getElementById('bfe2af9568874016839da0efa472f80b'), 'light', {renderer: 'canvas'});
#         var option_bfe2af9568874016839da0efa472f80b = {
#     "series": [
#         {
#             "type": "line",
#             "symbolSize": 4,
#             "showSymbol": false,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2019-09-21",
#                     93
#                 ],
#                 [
#                     "2019-09-22",
#                     734
#                 ],
#                 [
#                     "2019-09-23",
#                     1267
#                 ],
#                 [
#                     "2019-09-24",
#                     1929
#                 ],
#                 [
#                     "2019-09-25",
#                     2605
#                 ],
#                 [
#                     "2019-09-26",
#                     2935
#                 ],
#                 [
#                     "2019-09-27",
#                     3511
#                 ],
#                 [
#                     "2019-09-28",
#                     3803
#                 ],
#                 [
#                     "2019-09-29",
#                     4294
#                 ],
#                 [
#                     "2019-09-30",
#                     5225
#                 ],
#                 [
#                     "2019-10-01",
#                     5088
#                 ],
#                 [
#                     "2019-10-02",
#                     5386
#                 ],
#                 [
#                     "2019-10-03",
#                     6014
#                 ],
#                 [
#                     "2019-10-04",
#                     6221
#                 ],
#                 [
#                     "2019-10-05",
#                     6403
#                 ],
#                 [
#                     "2019-10-06",
#                     6641
#                 ],
#                 [
#                     "2019-10-07",
#                     7085
#                 ],
#                 [
#                     "2019-10-08",
#                     7097
#                 ],
#                 [
#                     "2019-10-09",
#                     6704
#                 ],
#                 [
#                     "2019-10-10",
#                     6715
#                 ],
#                 [
#                     "2019-10-11",
#                     6728
#                 ],
#                 [
#                     "2019-10-12",
#                     7267
#                 ],
#                 [
#                     "2019-10-13",
#                     7574
#                 ],
#                 [
#                     "2019-10-14",
#                     7719
#                 ],
#                 [
#                     "2019-10-15",
#                     8178
#                 ],
#                 [
#                     "2019-10-16",
#                     7940
#                 ],
#                 [
#                     "2019-10-17",
#                     8347
#                 ],
#                 [
#                     "2019-10-18",
#                     8861
#                 ],
#                 [
#                     "2019-10-19",
#                     9824
#                 ],
#                 [
#                     "2019-10-20",
#                     10609
#                 ],
#                 [
#                     "2019-10-21",
#                     20511
#                 ],
#                 [
#                     "2019-10-22",
#                     29686
#                 ],
#                 [
#                     "2019-10-23",
#                     31921
#                 ],
#                 [
#                     "2019-10-24",
#                     31851
#                 ],
#                 [
#                     "2019-10-25",
#                     30549
#                 ],
#                 [
#                     "2019-10-26",
#                     31014
#                 ],
#                 [
#                     "2019-10-27",
#                     31903
#                 ],
#                 [
#                     "2019-10-28",
#                     28793
#                 ],
#                 [
#                     "2019-10-29",
#                     27844
#                 ],
#                 [
#                     "2019-10-30",
#                     12603
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 1,
#                 "color": "cyan"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": true,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2019-09-21",
#                 "2019-09-22",
#                 "2019-09-23",
#                 "2019-09-24",
#                 "2019-09-25",
#                 "2019-09-26",
#                 "2019-09-27",
#                 "2019-09-28",
#                 "2019-09-29",
#                 "2019-09-30",
#                 "2019-10-01",
#                 "2019-10-02",
#                 "2019-10-03",
#                 "2019-10-04",
#                 "2019-10-05",
#                 "2019-10-06",
#                 "2019-10-07",
#                 "2019-10-08",
#                 "2019-10-09",
#                 "2019-10-10",
#                 "2019-10-11",
#                 "2019-10-12",
#                 "2019-10-13",
#                 "2019-10-14",
#                 "2019-10-15",
#                 "2019-10-16",
#                 "2019-10-17",
#                 "2019-10-18",
#                 "2019-10-19",
#                 "2019-10-20",
#                 "2019-10-21",
#                 "2019-10-22",
#                 "2019-10-23",
#                 "2019-10-24",
#                 "2019-10-25",
#                 "2019-10-26",
#                 "2019-10-27",
#                 "2019-10-28",
#                 "2019

# %% [markdown]
# ### 3.2 作品浏览量情况

# %%
bins = [0, 1, 2, 4, 1600]
item_df['浏览量等级'] = pd.cut(item_df['浏览量'], bins, labels=[f'({bins[x]}，{bins[x+1]}]' for x in range(len(bins)-1)])
data = item_df.groupby('浏览量等级')['浏览量'].count().reset_index().values.tolist()
pie_chart('作品浏览量分布', data).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="ad8db5109bf74c5ba4c7e12eb88df94e" style="width:550px; height:300px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_ad8db5109bf74c5ba4c7e12eb88df94e = echarts.init(
#             document.getElementById('ad8db5109bf74c5ba4c7e12eb88df94e'), 'light', {renderer: 'canvas'});
#         var option_ad8db5109bf74c5ba4c7e12eb88df94e = {
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "(0\uff0c1]",
#                     "value": 284761
#                 },
#                 {
#                     "name": "(1\uff0c2]",
#                     "value": 58970
#                 },
#                 {
#                     "name": "(2\uff0c4]",
#                     "value": 45281
#                 },
#                 {
#                     "name": "(4\uff0c1600]",
#                     "value": 60460
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "45%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12,
#                 "formatter": "{b}: {d}%"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "(0\uff0c1]",
#                 "(1\uff0c2]",
#                 "(2\uff0c4]",
#                 "(4\uff0c1600]"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "0%",
#             "top": "55",
#             "orient": "vertical"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u4f5c\u54c1\u6d4f\u89c8\u91cf\u5206\u5e03"
#         }
#     ]
# };
#         chart_ad8db5109bf74c5ba4c7e12eb88df94e.setOption(option_ad8db5109bf74c5ba4c7e12eb88df94e);
#     });
# </script>

# %% [markdown]
# ### 3.3 作品点量率情况

# %%
bins = [-1, 0, 1, 3, 5, 10, 35]
item_df['点赞等级'] = pd.cut(item_df['点赞量'], bins, labels=[f'[{bins[x]}，{bins[x+1]})' for x in range(len(bins)-1)], right=False)
data = item_df.groupby('点赞等级')['点赞量'].sum().reset_index().values.tolist()
pie_chart('点赞数分布', data).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="9f1f31cb93d743eab097582585c8f98e" style="width:550px; height:300px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_9f1f31cb93d743eab097582585c8f98e = echarts.init(
#             document.getElementById('9f1f31cb93d743eab097582585c8f98e'), 'light', {renderer: 'canvas'});
#         var option_9f1f31cb93d743eab097582585c8f98e = {
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "[-1\uff0c0)",
#                     "value": 0
#                 },
#                 {
#                     "name": "[0\uff0c1)",
#                     "value": 0
#                 },
#                 {
#                     "name": "[1\uff0c3)",
#                     "value": 13521
#                 },
#                 {
#                     "name": "[3\uff0c5)",
#                     "value": 1458
#                 },
#                 {
#                     "name": "[5\uff0c10)",
#                     "value": 1130
#                 },
#                 {
#                     "name": "[10\uff0c35)",
#                     "value": 629
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "45%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "fontSize": 12,
#                 "formatter": "{b}: {d}%"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "[-1\uff0c0)",
#                 "[0\uff0c1)",
#                 "[1\uff0c3)",
#                 "[3\uff0c5)",
#                 "[5\uff0c10)",
#                 "[10\uff0c35)"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "0%",
#             "top": "55",
#             "orient": "vertical"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u70b9\u8d5e\u6570\u5206\u5e03"
#         }
#     ]
# };
#         chart_9f1f31cb93d743eab097582585c8f98e.setOption(option_9f1f31cb93d743eab097582585c8f98e);
#     });
# </script>
